# %% [markdown]
# # method
# - through the count of push comment or total comment(push+boo+arrow)

# %% [markdown]
# # import module

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # analysis of board of movie with keyword constrait "國片"

# %%
df_movie_local = pd.read_json(r'.\result\movie_國片.json', lines=True)
df_movie_local['Date'] = [d.date() for d in df_movie_local['date']]
df_movie_local.set_index('Date', inplace=True)

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df_movie_local['total_comment'])):
    current_num = df_movie_local['total_comment'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df_movie_local['cumulative_total_comment'] = cumulative_total_comment_series

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df_movie_國片['push'])):
    current_num = df_movie_國片['push'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df_movie_國片['cumulative_push'] = cumulative_total_comment_series

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df_movie_國片['boo'])):
    current_num = df_movie_國片['boo'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df_movie_國片['cumulative_boo'] = cumulative_total_comment_series

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df_movie_國片['not-boo'])):
    current_num = df_movie_國片['not-boo'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df_movie_國片['cumulative_not_boo'] = cumulative_total_comment_series

# %%
df_movie_local['Day'] = [d.date() for d in df_movie_local['date']]
# Out:
#                     date                          title  \
# 0    2006-03-20 03:28:45    Re: [討論] 如果國片要用什麼題材 大家才會想看?
# 1    2006-09-25 23:29:17            [經典國片] 魯冰花 為貧寒的農民吶喊
# 2    2007-04-29 22:01:55                    [心得] 國片-練習曲
# 3    2007-06-20 06:55:13            [好雷] 國片-我的兒子是天才 小感想
# 4    2007-08-11 21:13:23          Re: 是周董有才華，還是國片的導演沒才華
# ...                  ...                            ...
# 1821 2021-12-28 19:22:16  Re: [大爛片] 一杯熱奶茶的等待，20年來最爛國片候選
# 1822 2022-01-01 22:04:26       [新聞] 邱澤《當男人》4億票房威奪國片年度冠軍
# 1823 2022-01-03 10:27:17   Fw: [新聞] 2022國片「恐怖元年」8部鬼片等上映
# 1824 2022-01-04 10:31:09               [問片] 請問一部國片裡面的台詞
# 1825 2022-01-05 17:30:50               [討論] 今年春節檔國片只有三部
#
#                                                 content  push  boo  arrow  \
# 0     ■　恐怖片　　雖然自己不常看恐怖片，不過這題材在國內個人覺得還漫值得發揮的！　　台灣在宗教及...    17    0      1
# 1     ※[本文轉錄自share看板]作者:MohLih(人間處處有溫情謝謝支持)看板:share標...     9    0      1
# ...

# %%
plt.figure(figsize=(15,5))
plt.plot(df_movie_國片.index, df_movie_國片['cumulative_total_comment'], label='cumulative_total_comment_count')
plt.plot(df_movie_國片.index, df_movie_國片['cumulative_push'], label = 'cumulative_push_count')
plt.plot(df_movie_國片.index, df_movie_國片['cumulative_boo'], label = 'cumulative_boo_count')
plt.plot(df_movie_國片.index, df_movie_國片['cumulative_not_boo'], label = 'cumulative_not_boo_count')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(df_movie_國片.index[1293:], df_movie_國片['total_comment'][1293:])
plt.title('movie_keyword_taiwan_total_comment_count')
plt.show()

# %% [markdown]
# # analysis of board of movie with keyword constraint "台灣"

# %%
df_movie_台灣 = pd.read_json(r'./result/movie_台灣.json', lines=True)
df_movie_台灣.set_index('date', inplace=True)
plt.figure(figsize=(15,5))
plt.plot(df_movie_台灣.index, df_movie_台灣['total_comment'])
plt.title('movie_keyword_taiwan_total_comment_count')
plt.show()

# %% [markdown]
# # analysis of board of movie with keyword constraint "臺灣"

# %%
df_movie_臺灣 = pd.read_json(r'./result/movie_臺灣.json', lines=True)
df_movie_臺灣.set_index('date', inplace=True)
plt.figure(figsize=(15,5))
plt.plot(df_movie_臺灣.index, df_movie_臺灣['total_comment'])
plt.title('movie_keyword_Taiwan_total_comment_count')
plt.show()

# %% [markdown]
# # analysis of board of Ourmovies with no constraint

# %%
df_Ourmovies_1000 = pd.read_json(r'.\result\Ourmovies_2000.json', lines=True)
df_Ourmovies_1000.set_index('date', inplace=True)
plt.figure(figsize=(15,5))
plt.plot(df_Ourmovies_1000.index, df_Ourmovies_1000['total_comment'])
plt.title('Ourmovies_newest_2000_total_comment_count')
plt.show()

# %% [markdown]
# # analysis of board of movie with keyword constraint "當男人戀愛時"

# %%
df_man_love = pd.read_json(r'./result/movie_當男人戀愛時.json', lines=True)
# df_man_love.set_index('date', inplace=True)

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df_man_love['total_comment'])):
    current_num = df_man_love['total_comment'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df_man_love['cumulative_total_comment'] = cumulative_total_comment_series

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df_man_love['push'])):
    current_num = df_man_love['push'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df_man_love['cumulative_push'] = cumulative_total_comment_series

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df_man_love['boo'])):
    current_num = df_man_love['boo'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df_man_love['cumulative_boo'] = cumulative_total_comment_series

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df_man_love['not-boo'])):
    current_num = df_man_love['not-boo'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df_man_love['cumulative_not_boo'] = cumulative_total_comment_series

# %%
df_man_love_merge = df_man_love[['cumulative_total_comment', 'cumulative_push']]
pd.to_datetime(df_man_love_merge.index, format='%Y%m%d')
df_man_love_merge
# Out:
#                      cumulative_total_comment  cumulative_push
# date
# 2014-04-12 11:39:03                         2                2
# 2014-06-09 13:58:59                         6                5
# 2020-09-06 09:12:18                         6                5
# 2021-02-23 17:53:57                        10                9
# 2021-03-26 17:24:57                        91               70
# ...                                       ...              ...
# 2021-09-22 19:24:11                      5648             2877
# 2021-09-24 01:03:29                      5648             2877
# 2021-11-27 14:20:20                      5667             2882
# 2021-12-15 10:13:03                      5688             2894
# 2021-12-25 00:28:01                      5742             2909
#
# [147 rows x 2 columns]

# %%
plt.figure(figsize=(15,5))
plt.plot(df.index[3:], df['cumulative_total_comment'][3:], label='cumulative_total_comment_count')
plt.plot(df.index[3:], df['cumulative_push'][3:], label = 'cumulative_push_count')
plt.legend()
plt.show()

# %% [markdown]
# # analysis of board of movie with keyword "月老"

# %%
df = pd.read_json(r'./result/movie_月老.json', lines=True)
df.set_index('date', inplace=True)

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df['total_comment'])):
    current_num = df['total_comment'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df['cumulative_total_comment'] = cumulative_total_comment_series

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df['push'])):
    current_num = df['push'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df['cumulative_push'] = cumulative_total_comment_series

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df['boo'])):
    current_num = df['boo'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df['cumulative_boo'] = cumulative_total_comment_series

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df['not-boo'])):
    current_num = df['not-boo'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df['cumulative_not_boo'] = cumulative_total_comment_series

# %%
plt.figure(figsize=(15,5))
plt.plot(df.index[3:], df['cumulative_total_comment'][303:], label='cumulative_total_comment_count')
plt.plot(df.index[3:], df['cumulative_push'][30:], label = 'cumulative_push_count')
plt.legend()
plt.show()

# %% [markdown]
# # analysis of board of movie with keyword "蜘蛛人"

# %%
df = pd.read_json(r'./result/movie_蜘蛛人_1000.json', lines=True)
df.set_index('date', inplace=True)
df.sort_index(inplace=True)

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df['total_comment'])):
    current_num = df['total_comment'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df['cumulative_total_comment'] = cumulative_total_comment_series

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df['push'])):
    current_num = df['push'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df['cumulative_push'] = cumulative_total_comment_series

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df['boo'])):
    current_num = df['boo'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df['cumulative_boo'] = cumulative_total_comment_series

cumulative_total_comment_series = []
cumulative_num = 0
for i in range(len(df['not-boo'])):
    current_num = df['not-boo'][i]
    cumulative_num += current_num
    cumulative_total_comment_series.append(cumulative_num)
df['cumulative_not_boo'] = cumulative_total_comment_series

# %%
plt.figure(figsize=(15,5))
plt.plot(df.index[100:], df['cumulative_total_comment'][100:], label='cumulative_total_comment_count')
plt.plot(df.index[100:], df['cumulative_push'][100:], label = 'cumulative_push_count')
plt.legend()
plt.show()
